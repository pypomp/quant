# %%
import os
#os.environ['XLA_PYTHON_CLIENT_PREALLOCATE']='false'

import jax
import itertools
import matplotlib.cm as cm
import numpy as np
import matplotlib
# Prevent ptitprince from raising cmap errors
cm.register_cmap = lambda name, cmap : matplotlib.colormaps.register(cmap, name=name)
import ptitprince as pt

import jax.numpy as jnp
import pypomp as pp
import ipywidgets as widgets
import pandas as pd
import copy

from jax import jit, grad
from functools import partial

from tqdm import tqdm


import matplotlib.pyplot as plt
plt.style.use('matplotlibrc')
np.set_printoptions(suppress=True)

# %%
from pypomp.train import _jgrad_mop
d = pp.dacca(gamma=False)
theta = d.theta
theta_orig = np.hstack(list(d.par_trans.to_est(theta[0]).values()))
grads = {'0.0' : [], '1.0' : [], '0.97' : []}
alphas = [0.,1.,0.97]
for i in tqdm(range(100)):
  for alpha in alphas:
    d.train(J=10000, M=1, 
                          theta=theta,
                        optimizer='SGD', eta=1, 
                          ls=False, scale=False, 
                          alpha=alpha, key=jax.random.PRNGKey(i))
    theta_new = np.hstack(list(d.par_trans.to_est(d.theta[0]).values()))
    grads[str(alpha)].append(theta_new - theta_orig)
# Out:
#   0%|          | 0/100 [00:07<?, ?it/s]
# ---------------------------------------------------------------------------
# JaxStackTraceBeforeTransformation         Traceback (most recent call last)
# File <frozen runpy>:198, in _run_module_as_main()
#
# File <frozen runpy>:88, in _run_code()
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/ipykernel_launcher.py:18
#      16 from ipykernel import kernelapp as app
# ---> 18 app.launch_new_instance()
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/traitlets/config/application.py:1075, in launch_instance()
#    1074 app.initialize(argv)
# -> 1075 app.start()
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/ipykernel/kernelapp.py:739, in start()
#     738 try:
# --> 739     self.io_loop.start()
#     740 except KeyboardInterrupt:
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/tornado/platform/asyncio.py:211, in start()
#     210 def start(self) -> None:
# --> 211     self.asyncio_loop.run_forever()
#
# File ~/anaconda3/envs/313/lib/python3.13/asyncio/base_events.py:683, in run_forever()
#     682 while True:
# --> 683     self._run_once()
#     684     if self._stopping:
#
# File ~/anaconda3/envs/313/lib/python3.13/asyncio/base_events.py:2042, in _run_once()
#    2041     else:
# -> 2042         handle._run()
#    2043 handle = None
#
# File ~/anaconda3/envs/313/lib/python3.13/asyncio/events.py:89, in _run()
#      88 try:
# ---> 89     self._context.run(self._callback, *self._args)
#      90 except (SystemExit, KeyboardInterrupt):
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/ipykernel/kernelbase.py:519, in dispatch_queue()
#     518 try:
# --> 519     await self.process_one()
#     520 except Exception:
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/ipykernel/kernelbase.py:508, in process_one()
#     506         self.control_stream.flush()
# --> 508 await dispatch(*args)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/ipykernel/kernelbase.py:400, in dispatch_shell()
#     399     if inspect.isawaitable(result):
# --> 400         await result
#     401 except Exception:
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/ipykernel/ipkernel.py:368, in execute_request()
#     367 self._associate_new_top_level_threads_with(parent_header)
# --> 368 await super().execute_request(stream, ident, parent)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/ipykernel/kernelbase.py:767, in execute_request()
#     766 if inspect.isawaitable(reply_content):
# --> 767     reply_content = await reply_content
#     769 # Flush output before sending the reply.
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/ipykernel/ipkernel.py:455, in do_execute()
#     454 if accepts_params["cell_id"]:
# --> 455     res = shell.run_cell(
#     456         code,
#     457         store_history=store_history,
#     458         silent=silent,
#     459         cell_id=cell_id,
#     460     )
#     461 else:
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/ipykernel/zmqshell.py:577, in run_cell()
#     576 self._last_traceback = None
# --> 577 return super().run_cell(*args, **kwargs)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3116, in run_cell()
#    3115 try:
# -> 3116     result = self._run_cell(
#    3117         raw_cell, store_history, silent, shell_futures, cell_id
#    3118     )
#    3119 finally:
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3171, in _run_cell()
#    3170 try:
# -> 3171     result = runner(coro)
#    3172 except BaseException as e:
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/IPython/core/async_helpers.py:128, in _pseudo_sync_runner()
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3394, in run_cell_async()
#    3391 interactivity = "none" if silent else self.ast_node_interactivity
# -> 3394 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3395        interactivity=interactivity, compiler=compiler, result=result)
#    3397 self.last_execution_succeeded = not has_raised
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3639, in run_ast_nodes()
#    3638     asy = compare(code)
# -> 3639 if await self.run_code(code, result, async_=asy):
#    3640     return True
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3699, in run_code()
#    3698     else:
# -> 3699         exec(code_obj, self.user_global_ns, self.user_ns)
#    3700 finally:
#    3701     # Reset our crash handler in place
#
# Cell In[2], line 9
#       8 for alpha in alphas:
# ----> 9   d.train(J=10000, M=1,
#      10                         theta=theta,
#      11                       optimizer='SGD', eta=1,
#      12                         ls=False, scale=False,
#      13                         alpha=alpha, key=jax.random.PRNGKey(i))
#      14   theta_new = np.hstack(list(d.par_trans.to_est(d.theta[0]).values()))
#
# File ~/OneDrive/Documents/UMich/Research/pypomp/pypomp/pypomp/pomp_class.py:693, in train()
#     691 n_obs = len(self.ys)
# --> 693 nLLs, theta_ests = _vmapped_train_internal(
#     694     theta_array,
#     695     jnp.array(self.ys),
#     696     self._dt_array_extended,
#     697     self._nstep_array,
#     698     self.t0,
#     699     jnp.array(self.ys.index),
#     700     self.rinit.struct_pf,
#     701     self.rproc.struct_pf_interp,
#     702     self.dmeas.struct_pf,
#     703     self.rproc.accumvars,
#     704     self._covars_extended,
#     705     J,
#     706     optimizer,
#     707     M,
#     708     eta,
#     709     c,
#     710     max_ls_itn,
#     711     thresh,
#     712     scale,
#     713     ls,
#     714     alpha,
#     715     keys,
#     716     n_monitors,
#     717     n_obs,
#     718 )
#     720 theta_ests_natural = np.stack(
#     721     [
#     722         self.par_trans.transform_array(
#    (...)    727     axis=0,
#     728 )
#
# File ~/OneDrive/Documents/UMich/Research/pypomp/pypomp/pypomp/train.py:285, in _train_internal()
#     283 # Run the optimization loop
#     284 final_theta, final_key, final_hess, Acopies, logliks, grads, hesses = (
# --> 285     jax.lax.fori_loop(
#     286         0,
#     287         M,
#     288         train_step,
#     289         (theta_ests, key, hess, Acopies, logliks, grads, hesses),
#     290     )
#     291 )
#     293 # Final evaluation
#
# File ~/OneDrive/Documents/UMich/Research/pypomp/pypomp/pypomp/train.py:92, in train_step()
#      91 key, subkey = jax.random.split(key)
# ---> 92 grad = _jgrad_mop(
#      93     theta_ests=theta_ests,
#      94     ys=ys,
#      95     dt_array_extended=dt_array_extended,
#      96     nstep_array=nstep_array,
#      97     t0=t0,
#      98     times=times,
#      99     J=J,
#     100     rinitializer=rinitializer,
#     101     rprocess=rprocess_interp,
#     102     dmeasure=dmeasure,
#     103     accumvars=accumvars,
#     104     covars_extended=covars_extended,
#     105     alpha=alpha,
#     106     key=subkey,
#     107 )
#     108 if n_monitors > 0:
#
# File ~/OneDrive/Documents/UMich/Research/pypomp/pypomp/pypomp/train.py:530, in _jgrad_mop()
#     521 """
#     522 Calculates the gradient of a mean MOP objective (function
#     523 'mop_internal_mean') w.r.t. the current estimated parameter value using
#    (...)    528         theta_ests.
#     529 """
# --> 530 return jax.grad(_mop_internal_mean)(
#     531     theta_ests,
#     532     ys=ys,
#     533     dt_array_extended=dt_array_extended,
#     534     nstep_array=nstep_array,
#     535     t0=t0,
#     536     times=times,
#     537     J=J,
#     538     rinitializer=rinitializer,
#     539     rprocess_interp=rprocess,
#     540     dmeasure=dmeasure,
#     541     accumvars=accumvars,
#     542     covars_extended=covars_extended,
#     543     alpha=alpha,
#     544     key=key,
#     545 )
#
# File ~/OneDrive/Documents/UMich/Research/pypomp/pypomp/pypomp/mop.py:94, in _mop_internal_mean()
#      90 """
#      91 Internal function for calculating the MOP estimate of the log likelihood divided by
#      92 the length of the observations. This is used in internal pypomp.train functions.
#      93 """
# ---> 94 return _mop_internal(
#      95     theta=theta,
#      96     dt_array_extended=dt_array_extended,
#      97     nstep_array=nstep_array,
#      98     t0=t0,
#      99     times=times,
#     100     ys=ys,
#     101     J=J,
#     102     rinitializer=rinitializer,
#     103     rprocess_interp=rprocess_interp,
#     104     dmeasure=dmeasure,
#     105     covars_extended=covars_extended,
#     106     accumvars=accumvars,
#     107     alpha=alpha,
#     108     key=key,
#     109 ) / len(ys)
#
# File ~/OneDrive/Documents/UMich/Research/pypomp/pypomp/pypomp/mop.py:63, in _mop_internal()
#      47 mop_helper_2 = jax.checkpoint(  # type: ignore[reportAttributeAccessIssue]
#      48     partial(
#      49         _mop_helper,
#    (...)     60     )
#      61 )
# ---> 63 t, particlesF, loglik, weightsF, counts, key, obs_idx = jax.lax.fori_loop(
#      64     lower=0,
#      65     upper=len(ys),
#      66     body_fun=mop_helper_2,
#      67     init_val=(t0, particlesF, loglik, weightsF, counts, key, 0),
#      68 )
#      70 return -loglik
#
# File ~/OneDrive/Documents/UMich/Research/pypomp/pypomp/pypomp/mop.py:137, in _mop_helper()
#     135 weightsP = alpha * weightsF
# --> 137 key, keys = _keys_helper(key=key, J=J, covars=covars_extended)
#     138 nstep = nstep_array[i].astype(int)
#
# File ~/OneDrive/Documents/UMich/Research/pypomp/pypomp/pypomp/internal_functions.py:22, in _keys_helper()
#      21 else:
# ---> 22     key, *keys = jax.random.split(key, num=J + 1)
#      23     keys = jnp.array(keys)
#
# JaxStackTraceBeforeTransformation: KeyboardInterrupt
#
# The preceding stack trace is the source of the JAX operation that, once transformed by JAX, triggered the following exception.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 9
#       7 for i in tqdm(range(100)):
#       8   for alpha in alphas:
# ----> 9     d.train(J=10000, M=1,
#      10                           theta=theta,
#      11                         optimizer='SGD', eta=1,
#      12                           ls=False, scale=False,
#      13                           alpha=alpha, key=jax.random.PRNGKey(i))
#      14     theta_new = np.hstack(list(d.par_trans.to_est(d.theta[0]).values()))
#      15     grads[str(alpha)].append(theta_new - theta_orig)
#
# File ~/OneDrive/Documents/UMich/Research/pypomp/pypomp/pypomp/pomp_class.py:693, in Pomp.train(self, J, M, eta, key, theta, optimizer, alpha, thresh, scale, ls, c, max_ls_itn, n_monitors, track_time)
#     684 theta_array = jnp.array(
#     685     [
#     686         _theta_dict_to_array(theta_i, self.canonical_param_names)
#     687         for theta_i in theta_list_trans
#     688     ]
#     689 )
#     691 n_obs = len(self.ys)
# --> 693 nLLs, theta_ests = _vmapped_train_internal(
#     694     theta_array,
#     695     jnp.array(self.ys),
#     696     self._dt_array_extended,
#     697     self._nstep_array,
#     698     self.t0,
#     699     jnp.array(self.ys.index),
#     700     self.rinit.struct_pf,
#     701     self.rproc.struct_pf_interp,
#     702     self.dmeas.struct_pf,
#     703     self.rproc.accumvars,
#     704     self._covars_extended,
#     705     J,
#     706     optimizer,
#     707     M,
#     708     eta,
#     709     c,
#     710     max_ls_itn,
#     711     thresh,
#     712     scale,
#     713     ls,
#     714     alpha,
#     715     keys,
#     716     n_monitors,
#     717     n_obs,
#     718 )
#     720 theta_ests_natural = np.stack(
#     721     [
#     722         self.par_trans.transform_array(
#    (...)    727     axis=0,
#     728 )
#     730 joined_array = xr.DataArray(
#     731     np.concatenate(
#     732         [
#    (...)    743     },
#     744 )
#
#     [... skipping hidden 1 frame]
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/api.py:1112, in vmap.<locals>.vmap_f(*args, **kwargs)
#    1109 try:
#    1110   axis_data = batching.AxisData(axis_name, axis_size_, spmd_axis_name,
#    1111                                 explicit_mesh_axis)
# -> 1112   out_flat = batching.batch(
#    1113       flat_fun, axis_data, in_axes_flat,
#    1114       lambda: flatten_axes("vmap out_axes", out_tree(), out_axes)
#    1115   ).call_wrapped(*args_flat)
#    1116 except batching.SpecMatchError as e:
#    1117   out_axes_flat = flatten_axes("vmap out_axes", out_tree(), out_axes)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/linear_util.py:212, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     210 def call_wrapped(self, *args, **kwargs):
#     211   """Calls the transformed function"""
# --> 212   return self.f_transformed(*args, **kwargs)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/interpreters/batching.py:644, in _batch_outer(f, axis_data, in_dims, *in_vals)
#     642 tag = TraceTag()
#     643 with source_info_util.transform_name_stack('vmap'):
# --> 644   outs, trace = f(tag, in_dims, *in_vals)
#     645 with core.ensure_no_leaks(trace): del trace
#     646 return outs
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/interpreters/batching.py:660, in _batch_inner(f, axis_data, out_dim_dests, tag, in_dims, *in_vals)
#     656   in_tracers = map(partial(to_elt, trace, idx), in_vals, in_dims)
#     657 with (core.set_current_trace(trace),
#     658       core.extend_axis_env_nd([(axis_data.name, axis_data.size)]),
#     659       core.add_spmd_axis_names(axis_data.spmd_name)):
# --> 660   outs = f(*in_tracers)
#     661   out_dim_dests = out_dim_dests() if callable(out_dim_dests) else out_dim_dests
#     662   out_vals = map(partial(from_elt, trace, axis_data.size, axis_data.explicit_mesh_axis),
#     663                  range(len(outs)), outs, out_dim_dests)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/interpreters/batching.py:342, in flatten_fun_for_vmap(f, store, in_tree, *args_flat)
#     338 @lu.transformation_with_aux2
#     339 def flatten_fun_for_vmap(f: Callable,
#     340                          store: lu.Store, in_tree: PyTreeDef, *args_flat):
#     341   py_args, py_kwargs = tree_unflatten(in_tree, args_flat)
# --> 342   ans = f(*py_args, **py_kwargs)
#     343   ans, out_tree = tree_flatten(ans, is_leaf=is_vmappable)
#     344   store.store(out_tree)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/linear_util.py:397, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     395 @transformation_with_aux2
#     396 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 397   ans = _fun(*args, **kwargs)
#     398   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     399   if _store:
#     400     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     401     # the bwd function in a custom_vjp
#
#     [... skipping hidden 1 frame]
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/pjit.py:270, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     265 if config.no_tracing.value:
#     266   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     267                      "`jit`, but 'no_tracing' is set")
#     269 (outs, out_flat, out_tree, args_flat, jaxpr,
# --> 270  executable, pgle_profiler, const_args) = _python_pjit_helper(
#     271      fun, jit_info, *args, **kwargs)
#     273 maybe_fastpath_data = _get_fastpath_data(
#     274     executable, out_tree, args_flat, out_flat, jaxpr.effects, jaxpr.consts,
#     275     jit_info.abstracted_axes, pgle_profiler,
#     276     const_args)
#     278 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/pjit.py:139, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     138 def _python_pjit_helper(fun: Callable, jit_info: PjitInfo, *args, **kwargs):
# --> 139   p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#     141   for arg in args_flat:
#     142     dispatch.check_arg(arg)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/pjit.py:643, in _infer_params(fun, ji, args, kwargs)
#     641     return _infer_params_internal(fun, ji, args, kwargs)
#     642 else:
# --> 643   return _infer_params_internal(fun, ji, args, kwargs)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/pjit.py:667, in _infer_params_internal(fun, ji, args, kwargs)
#     664 entry = _infer_params_cached(fun, ji, signature, avals, ctx_mesh)
#     666 if entry.pjit_params is None:
# --> 667   p, args_flat = _infer_params_impl(
#     668       fun, ji, ctx_mesh, dbg, args, kwargs, in_avals=avals)
#     669   if p.params['jaxpr'].jaxpr.is_high:
#     670     return p, p.consts + args_flat
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/pjit.py:564, in _infer_params_impl(***failed resolving arguments***)
#     557 in_shardings_flat, in_layouts_flat = _process_in_axis_resources(
#     558     in_shardings_treedef, in_shardings_leaves,
#     559     ji.in_layouts_treedef, ji.in_layouts_leaves,
#     560     in_avals, in_tree, flat_fun.debug_info, device_or_backend_set, have_kwargs)
#     562 qdd_token = _qdd_cache_index(flat_fun, in_type)
# --> 564 jaxpr, consts, out_avals = _create_pjit_jaxpr(
#     565     flat_fun, in_type, qdd_token, IgnoreKey(ji.inline))
#     566 if config.mutable_array_checks.value:
#     567   _check_no_aliased_closed_over_refs(dbg, (*jaxpr.consts, *consts), explicit_args)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/linear_util.py:472, in cache.<locals>.memoized_fun(fun, *args)
#     470 if do_explain := explain and config.explain_cache_misses.value:
#     471   start = time.time()
# --> 472 ans = call(fun, *args)
#     473 if do_explain:
#     474   explain(fun, cache is new_cache, cache, key, time.time() - start)  # type: ignore
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/pjit.py:1351, in _create_pjit_jaxpr(***failed resolving arguments***)
#    1348     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic2(
#    1349         lu.annotate(fun, cast(core.InputType, in_type)))
#    1350   else:
# -> 1351     jaxpr, global_out_avals, consts = pe.trace_to_jaxpr_dynamic(fun, in_type)
#    1353 if config.debug_key_reuse.value:
#    1354   # Import here to avoid circular imports
#    1355   from jax.experimental.key_reuse._core import check_key_reuse_jaxpr  # pytype: disable=import-error
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/profiler.py:364, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     361 @wraps(func)
#     362 def wrapper(*args, **kwargs):
#     363   with TraceAnnotation(name, **decorator_kwargs):
# --> 364     return func(*args, **kwargs)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/interpreters/partial_eval.py:2350, in trace_to_jaxpr_dynamic(fun, in_avals, keep_inputs, lower, auto_dce)
#    2347 in_tracers = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
#    2349 with core.set_current_trace(trace):
# -> 2350   ans = fun.call_wrapped(*in_tracers)
#    2351 _check_returned_jaxtypes(fun.debug_info, ans)
#    2352 out_tracers = map(partial(trace.to_jaxpr_tracer, source_info=source_info), ans)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/linear_util.py:212, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     210 def call_wrapped(self, *args, **kwargs):
#     211   """Calls the transformed function"""
# --> 212   return self.f_transformed(*args, **kwargs)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/api_util.py:73, in flatten_fun(f, store, in_tree, *args_flat)
#      69 @lu.transformation_with_aux2
#      70 def flatten_fun(f: Callable, store: lu.Store,
#      71                 in_tree: PyTreeDef, *args_flat):
#      72   py_args, py_kwargs = tree_unflatten(in_tree, args_flat)
# ---> 73   ans = f(*py_args, **py_kwargs)
#      74   ans, out_tree = tree_flatten(ans)
#      75   store.store(out_tree)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/api_util.py:314, in _argnames_partial(_fun, _fixed_kwargs, *args, **dyn_kwargs)
#     311 @lu.transformation2
#     312 def _argnames_partial(_fun, _fixed_kwargs: WrapKwArgs, *args, **dyn_kwargs):
#     313   kwargs = dict({k: v.val for k, v in _fixed_kwargs.val.items()}, **dyn_kwargs)
# --> 314   return _fun(*args, **kwargs)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/api_util.py:288, in _argnums_partial(_fun, _dyn_argnums, _fixed_args, *dyn_args, **kwargs)
#     286 args = [next(fixed_args_).val if x is sentinel else x for x in args]
#     287 assert next(fixed_args_, sentinel) is sentinel
# --> 288 return _fun(*args, **kwargs)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/linear_util.py:397, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     395 @transformation_with_aux2
#     396 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 397   ans = _fun(*args, **kwargs)
#     398   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     399   if _store:
#     400     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     401     # the bwd function in a custom_vjp
#
# File ~/OneDrive/Documents/UMich/Research/pypomp/pypomp/pypomp/train.py:285, in _train_internal(theta_ests, ys, dt_array_extended, nstep_array, t0, times, rinitializer, rprocess_interp, dmeasure, accumvars, covars_extended, J, optimizer, M, eta, c, max_ls_itn, thresh, scale, ls, alpha, key, n_monitors, n_obs)
#     281 hess = jnp.eye(theta_ests.shape[-1])  # default one
#     283 # Run the optimization loop
#     284 final_theta, final_key, final_hess, Acopies, logliks, grads, hesses = (
# --> 285     jax.lax.fori_loop(
#     286         0,
#     287         M,
#     288         train_step,
#     289         (theta_ests, key, hess, Acopies, logliks, grads, hesses),
#     290     )
#     291 )
#     293 # Final evaluation
#     294 if n_monitors > 0:
#
#     [... skipping hidden 1 frame]
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/lax/control_flow/loops.py:2503, in fori_loop(lower, upper, body_fun, init_val, unroll)
#    2501     return init_val
#    2502   scan_body = _fori_scan_body_fun(body_fun, body_fun_dbg)
# -> 2503   (_, result), _ = scan(
#    2504       scan_body,
#    2505       (lower_, init_val),
#    2506       None,
#    2507       length=length,
#    2508       unroll=unroll,
#    2509   )
#    2510   return result
#    2511 if unroll is not None and unroll is not False and unroll != 1:
#
#     [... skipping hidden 1 frame]
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/lax/control_flow/loops.py:299, in scan(f, init, xs, length, reverse, unroll, _split_transpose)
#     291   return (init_flat, carry_avals, carry_avals_out, init_tree, in_flat, jaxpr,
#     292           consts, out_tree, out_tree_children)
#     294 # The carry input and output avals must match exactly. However, we want to account for
#     295 # the case when init contains weakly-typed values (e.g. Python scalars), with avals that
#     296 # may not match the output despite being compatible by virtue of their weak type.
#     297 # To do this, we compute the jaxpr in two passes: first with the raw inputs, and if
#     298 # necessary, a second time with modified init values.
# --> 299 init_flat, carry_avals, carry_avals_out, init_tree, *rest = _create_jaxpr(init)
#     300 new_init_flat, changed = _promote_weak_typed_inputs(init_flat, carry_avals, carry_avals_out)
#     301 if changed:
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/lax/control_flow/loops.py:281, in scan.<locals>._create_jaxpr(init)
#     279 in_flat, in_tree = tree_flatten((init, xs))
#     280 carry_avals = tuple(_map(core.get_aval, init_flat))
# --> 281 jaxpr, consts, out_tree = _initial_style_jaxpr(
#     282     f, in_tree, (*carry_avals, *x_avals), debug_info=dbg_body)
#     283 if config.mutable_array_checks.value:
#     284   _check_no_aliased_closed_over_refs(dbg_body, (*jaxpr.consts, *consts), in_flat)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/lax/control_flow/common.py:63, in _initial_style_jaxpr(fun, in_tree, in_avals, debug_info)
#      58 @weakref_lru_cache
#      59 def _initial_style_jaxpr(fun: Callable,
#      60                          in_tree: PyTreeDef,
#      61                          in_avals: Sequence[core.AbstractValue],
#      62                          debug_info: core.DebugInfo) -> tuple[core.ClosedJaxpr, Sequence[Any], PyTreeDef]:
# ---> 63   jaxpr, consts, out_tree = _initial_style_open_jaxpr(
#      64       fun, in_tree, in_avals, debug_info)
#      65   closed_jaxpr = pe.close_jaxpr(pe.convert_constvars_jaxpr(jaxpr))
#      66   return closed_jaxpr, consts, out_tree
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/lax/control_flow/common.py:55, in _initial_style_open_jaxpr(fun, in_tree, in_avals, debug_info)
#      47 @weakref_lru_cache
#      48 def _initial_style_open_jaxpr(fun: Callable,
#      49                               in_tree: PyTreeDef,
#      50                               in_avals: Sequence[core.AbstractValue],
#      51                               debug_info: core.DebugInfo):
#      52   wrapped_fun, out_tree = api_util.flatten_fun_nokwargs(
#      53       lu.wrap_init(fun, debug_info=debug_info),
#      54       in_tree)
# ---> 55   jaxpr, _, consts = pe.trace_to_jaxpr_dynamic(wrapped_fun, in_avals)
#      56   return jaxpr, consts, out_tree()
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/profiler.py:364, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     361 @wraps(func)
#     362 def wrapper(*args, **kwargs):
#     363   with TraceAnnotation(name, **decorator_kwargs):
# --> 364     return func(*args, **kwargs)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/interpreters/partial_eval.py:2350, in trace_to_jaxpr_dynamic(fun, in_avals, keep_inputs, lower, auto_dce)
#    2347 in_tracers = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
#    2349 with core.set_current_trace(trace):
# -> 2350   ans = fun.call_wrapped(*in_tracers)
#    2351 _check_returned_jaxtypes(fun.debug_info, ans)
#    2352 out_tracers = map(partial(trace.to_jaxpr_tracer, source_info=source_info), ans)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/linear_util.py:212, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     210 def call_wrapped(self, *args, **kwargs):
#     211   """Calls the transformed function"""
# --> 212   return self.f_transformed(*args, **kwargs)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/api_util.py:90, in flatten_fun_nokwargs(f, store, in_tree, *args_flat)
#      86 @lu.transformation_with_aux2
#      87 def flatten_fun_nokwargs(f: Callable, store: lu.Store,
#      88                          in_tree: PyTreeDef, *args_flat):
#      89   py_args = tree_unflatten(in_tree, args_flat)
# ---> 90   ans = f(*py_args)
#      91   ans, out_tree = tree_flatten(ans)
#      92   store.store(out_tree)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/linear_util.py:397, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     395 @transformation_with_aux2
#     396 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 397   ans = _fun(*args, **kwargs)
#     398   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     399   if _store:
#     400     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     401     # the bwd function in a custom_vjp
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/lax/control_flow/loops.py:2388, in _fori_scan_body_fun.<locals>.scanned_fun(loop_carry, _)
#    2386 def scanned_fun(loop_carry, _):
#    2387   i, x = loop_carry
# -> 2388   return (i + 1, body_fun_ref()(i, x)), None
#
# File ~/OneDrive/Documents/UMich/Research/pypomp/pypomp/pypomp/train.py:92, in _train_internal.<locals>.train_step(i, carry)
#      90 else:
#      91     key, subkey = jax.random.split(key)
# ---> 92     grad = _jgrad_mop(
#      93         theta_ests=theta_ests,
#      94         ys=ys,
#      95         dt_array_extended=dt_array_extended,
#      96         nstep_array=nstep_array,
#      97         t0=t0,
#      98         times=times,
#      99         J=J,
#     100         rinitializer=rinitializer,
#     101         rprocess=rprocess_interp,
#     102         dmeasure=dmeasure,
#     103         accumvars=accumvars,
#     104         covars_extended=covars_extended,
#     105         alpha=alpha,
#     106         key=subkey,
#     107     )
#     108     if n_monitors > 0:
#     109         key, *subkeys = jax.random.split(key, n_monitors + 1)
#
# File ~/OneDrive/Documents/UMich/Research/pypomp/pypomp/pypomp/train.py:530, in _jgrad_mop(theta_ests, ys, dt_array_extended, nstep_array, t0, times, J, rinitializer, rprocess, dmeasure, accumvars, covars_extended, alpha, key)
#     505 def _jgrad_mop(
#     506     theta_ests: jax.Array,
#     507     ys: jax.Array,
#    (...)    519     key: jax.Array,
#     520 ):
#     521     """
#     522     Calculates the gradient of a mean MOP objective (function
#     523     'mop_internal_mean') w.r.t. the current estimated parameter value using
#    (...)    528             theta_ests.
#     529     """
# --> 530     return jax.grad(_mop_internal_mean)(
#     531         theta_ests,
#     532         ys=ys,
#     533         dt_array_extended=dt_array_extended,
#     534         nstep_array=nstep_array,
#     535         t0=t0,
#     536         times=times,
#     537         J=J,
#     538         rinitializer=rinitializer,
#     539         rprocess_interp=rprocess,
#     540         dmeasure=dmeasure,
#     541         accumvars=accumvars,
#     542         covars_extended=covars_extended,
#     543         alpha=alpha,
#     544         key=key,
#     545     )
#
#     [... skipping hidden 1 frame]
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/api.py:406, in grad.<locals>.grad_f(*args, **kwargs)
#     403 @wraps(fun, docstr=docstr, argnums=argnums)
#     404 @api_boundary
#     405 def grad_f(*args, **kwargs):
# --> 406   _, g = value_and_grad_f(*args, **kwargs)
#     407   return g
#
#     [... skipping hidden 1 frame]
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/api.py:479, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     477   _check_input_dtype_grad(holomorphic, allow_int, leaf)
#     478 if not has_aux:
# --> 479   ans, vjp_py = _vjp(f_partial, *dyn_args)
#     480 else:
#     481   ans, vjp_py, aux = _vjp(f_partial, *dyn_args, has_aux=True)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/api.py:2144, in _vjp(fun, has_aux, *primals)
#    2142 if not has_aux:
#    2143   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2144   out_primals, vjp = ad.vjp(flat_fun, primals_flat)
#    2145   out_tree = out_tree()
#    2146 else:
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:312, in vjp(traceable, primals, has_aux)
#     310 def vjp(traceable: lu.WrappedFun, primals, has_aux=False):
#     311   if not has_aux:
# --> 312     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     313   else:
#     314     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:286, in linearize(traceable, *primals, **kwargs)
#     284 has_aux = kwargs.pop('has_aux', False)
#     285 if config.use_direct_linearize.value:
# --> 286   return direct_linearize(traceable, primals, kwargs, has_aux=has_aux)
#     287 if not has_aux:
#     288   jvpfun = jvp(traceable)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:259, in direct_linearize(traceable, primals, kwargs, has_aux, tag)
#     254   aux_primals = [x.primal
#     255                  if isinstance(x, LinearizeTracer)
#     256                  and x._trace.tag is linearize_trace.tag
#     257                  else x for x in aux]
#     258 else:
# --> 259   ans = traceable.call_wrapped(*tracers)
#     260   aux = None
#     261 out_primals, out_tangents = unzip2(map(linearize_trace.to_primal_tangent_pair, ans))
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/linear_util.py:212, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     210 def call_wrapped(self, *args, **kwargs):
#     211   """Calls the transformed function"""
# --> 212   return self.f_transformed(*args, **kwargs)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/api_util.py:90, in flatten_fun_nokwargs(f, store, in_tree, *args_flat)
#      86 @lu.transformation_with_aux2
#      87 def flatten_fun_nokwargs(f: Callable, store: lu.Store,
#      88                          in_tree: PyTreeDef, *args_flat):
#      89   py_args = tree_unflatten(in_tree, args_flat)
# ---> 90   ans = f(*py_args)
#      91   ans, out_tree = tree_flatten(ans)
#      92   store.store(out_tree)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/api_util.py:288, in _argnums_partial(_fun, _dyn_argnums, _fixed_args, *dyn_args, **kwargs)
#     286 args = [next(fixed_args_).val if x is sentinel else x for x in args]
#     287 assert next(fixed_args_, sentinel) is sentinel
# --> 288 return _fun(*args, **kwargs)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/linear_util.py:397, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     395 @transformation_with_aux2
#     396 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 397   ans = _fun(*args, **kwargs)
#     398   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     399   if _store:
#     400     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     401     # the bwd function in a custom_vjp
#
#     [... skipping hidden 1 frame]
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/pjit.py:270, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     265 if config.no_tracing.value:
#     266   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     267                      "`jit`, but 'no_tracing' is set")
#     269 (outs, out_flat, out_tree, args_flat, jaxpr,
# --> 270  executable, pgle_profiler, const_args) = _python_pjit_helper(
#     271      fun, jit_info, *args, **kwargs)
#     273 maybe_fastpath_data = _get_fastpath_data(
#     274     executable, out_tree, args_flat, out_flat, jaxpr.effects, jaxpr.consts,
#     275     jit_info.abstracted_axes, pgle_profiler,
#     276     const_args)
#     278 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/pjit.py:152, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     149   out_flat, compiled, profiler, const_args = _pjit_call_impl_python(
#     150       *args_flat, **p.params)
#     151 else:
# --> 152   out_flat = jit_p.bind(*args_flat, **p.params)
#     153   compiled = None
#     154   profiler = None
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/core.py:612, in Primitive.bind(self, *args, **params)
#     610 def bind(self, *args, **params):
#     611   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 612   return self._true_bind(*args, **params)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/core.py:628, in Primitive._true_bind(self, *args, **params)
#     626 trace_ctx.set_trace(eval_trace)
#     627 try:
# --> 628   return self.bind_with_trace(prev_trace, args, params)
#     629 finally:
#     630   trace_ctx.set_trace(prev_trace)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/core.py:638, in Primitive.bind_with_trace(self, trace, args, params)
#     635   with set_current_trace(trace):
#     636     return self.to_lojax(*args, **params)  # type: ignore
# --> 638 return trace.process_primitive(self, args, params)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:891, in LinearizeTrace.process_primitive(self, primitive, args, params)
#     889 lin = primitive_linearizations.get(primitive, fallback)
#     890 with core.set_current_trace(self.parent_trace):
# --> 891   primal_out, tangent_nzs_out, residuals, linearized = lin(
#     892       tangent_nzs, *primals_in, **params)
#     893 with (core.set_current_trace(self.tangent_trace),
#     894       source_info_util.set_name_stack(self._name_stack_suffix())):
#     895   tangent_out = linearized(residuals, *tangents_in)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/pjit.py:2231, in _pjit_linearize(nzs, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *primals_in)
#    2227 def _pjit_linearize(nzs, *primals_in, jaxpr, in_shardings, out_shardings,
#    2228                     in_layouts, out_layouts, donated_invars, ctx_mesh, name,
#    2229                     keep_unused, inline, compiler_options_kvs):
#    2230   primal_jaxpr, num_residuals_out, nzs_out, in_fwd_res, tangent_jaxpr = \
# -> 2231       ad.linearize_jaxpr(jaxpr, nzs)
#    2232   num_residuals_in = len(in_fwd_res)
#    2233   num_primals_out = len(primal_jaxpr.out_avals) - num_residuals_out
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:166, in linearize_jaxpr(jaxpr, nonzeros, instantiate, allow_fwds)
#     164   instantiate = (instantiate,) * len(jaxpr.jaxpr.outvars)
#     165 assert len(instantiate) == len(jaxpr.jaxpr.outvars)
# --> 166 return _linearize_jaxpr(jaxpr, tuple(nonzeros), tuple(instantiate),
#     167                         tuple(allow_fwds))
#
# File ~/anaconda3/envs/313/lib/python3.13/contextlib.py:85, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      82 @wraps(func)
#      83 def inner(*args, **kwds):
#      84     with self._recreate_cm():
# ---> 85         return func(*args, **kwds)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:195, in _linearize_jaxpr(jaxpr, nonzeros, instantiate, allow_fwds)
#     192 in_primals = [t.primal for t in tracers]
#     194 with core.set_current_trace(lin_trace, check_leaks=True):
# --> 195   ans = core.eval_jaxpr(jaxpr.jaxpr, jaxpr.consts, *tracers)
#     196   out_primals, out_tangents = unzip2(map(lin_trace.to_primal_tangent_pair, ans))
#     197   out_tangents = [instantiate_zeros(t) if inst else t
#     198                   for t, inst in zip(out_tangents, instantiate)]
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/core.py:722, in eval_jaxpr(jaxpr, consts, propagate_source_info, *args)
#     719 traceback = eqn.source_info.traceback if propagate_source_info else None
#     720 with source_info_util.user_context(
#     721     traceback, name_stack=name_stack), eqn.ctx.manager:
# --> 722   ans = eqn.primitive.bind(*subfuns, *map(read, eqn.invars), **bind_params)
#     723 if eqn.primitive.multiple_results:
#     724   foreach(write, eqn.outvars, ans)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/core.py:612, in Primitive.bind(self, *args, **params)
#     610 def bind(self, *args, **params):
#     611   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 612   return self._true_bind(*args, **params)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/core.py:628, in Primitive._true_bind(self, *args, **params)
#     626 trace_ctx.set_trace(eval_trace)
#     627 try:
# --> 628   return self.bind_with_trace(prev_trace, args, params)
#     629 finally:
#     630   trace_ctx.set_trace(prev_trace)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/core.py:638, in Primitive.bind_with_trace(self, trace, args, params)
#     635   with set_current_trace(trace):
#     636     return self.to_lojax(*args, **params)  # type: ignore
# --> 638 return trace.process_primitive(self, args, params)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:891, in LinearizeTrace.process_primitive(self, primitive, args, params)
#     889 lin = primitive_linearizations.get(primitive, fallback)
#     890 with core.set_current_trace(self.parent_trace):
# --> 891   primal_out, tangent_nzs_out, residuals, linearized = lin(
#     892       tangent_nzs, *primals_in, **params)
#     893 with (core.set_current_trace(self.tangent_trace),
#     894       source_info_util.set_name_stack(self._name_stack_suffix())):
#     895   tangent_out = linearized(residuals, *tangents_in)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/pjit.py:2231, in _pjit_linearize(nzs, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *primals_in)
#    2227 def _pjit_linearize(nzs, *primals_in, jaxpr, in_shardings, out_shardings,
#    2228                     in_layouts, out_layouts, donated_invars, ctx_mesh, name,
#    2229                     keep_unused, inline, compiler_options_kvs):
#    2230   primal_jaxpr, num_residuals_out, nzs_out, in_fwd_res, tangent_jaxpr = \
# -> 2231       ad.linearize_jaxpr(jaxpr, nzs)
#    2232   num_residuals_in = len(in_fwd_res)
#    2233   num_primals_out = len(primal_jaxpr.out_avals) - num_residuals_out
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:166, in linearize_jaxpr(jaxpr, nonzeros, instantiate, allow_fwds)
#     164   instantiate = (instantiate,) * len(jaxpr.jaxpr.outvars)
#     165 assert len(instantiate) == len(jaxpr.jaxpr.outvars)
# --> 166 return _linearize_jaxpr(jaxpr, tuple(nonzeros), tuple(instantiate),
#     167                         tuple(allow_fwds))
#
# File ~/anaconda3/envs/313/lib/python3.13/contextlib.py:85, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      82 @wraps(func)
#      83 def inner(*args, **kwds):
#      84     with self._recreate_cm():
# ---> 85         return func(*args, **kwds)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:195, in _linearize_jaxpr(jaxpr, nonzeros, instantiate, allow_fwds)
#     192 in_primals = [t.primal for t in tracers]
#     194 with core.set_current_trace(lin_trace, check_leaks=True):
# --> 195   ans = core.eval_jaxpr(jaxpr.jaxpr, jaxpr.consts, *tracers)
#     196   out_primals, out_tangents = unzip2(map(lin_trace.to_primal_tangent_pair, ans))
#     197   out_tangents = [instantiate_zeros(t) if inst else t
#     198                   for t, inst in zip(out_tangents, instantiate)]
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/core.py:722, in eval_jaxpr(jaxpr, consts, propagate_source_info, *args)
#     719 traceback = eqn.source_info.traceback if propagate_source_info else None
#     720 with source_info_util.user_context(
#     721     traceback, name_stack=name_stack), eqn.ctx.manager:
# --> 722   ans = eqn.primitive.bind(*subfuns, *map(read, eqn.invars), **bind_params)
#     723 if eqn.primitive.multiple_results:
#     724   foreach(write, eqn.outvars, ans)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/core.py:612, in Primitive.bind(self, *args, **params)
#     610 def bind(self, *args, **params):
#     611   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 612   return self._true_bind(*args, **params)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/core.py:628, in Primitive._true_bind(self, *args, **params)
#     626 trace_ctx.set_trace(eval_trace)
#     627 try:
# --> 628   return self.bind_with_trace(prev_trace, args, params)
#     629 finally:
#     630   trace_ctx.set_trace(prev_trace)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/core.py:638, in Primitive.bind_with_trace(self, trace, args, params)
#     635   with set_current_trace(trace):
#     636     return self.to_lojax(*args, **params)  # type: ignore
# --> 638 return trace.process_primitive(self, args, params)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:891, in LinearizeTrace.process_primitive(self, primitive, args, params)
#     889 lin = primitive_linearizations.get(primitive, fallback)
#     890 with core.set_current_trace(self.parent_trace):
# --> 891   primal_out, tangent_nzs_out, residuals, linearized = lin(
#     892       tangent_nzs, *primals_in, **params)
#     893 with (core.set_current_trace(self.tangent_trace),
#     894       source_info_util.set_name_stack(self._name_stack_suffix())):
#     895   tangent_out = linearized(residuals, *tangents_in)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/lax/control_flow/loops.py:642, in _scan_linearize(nzs, reverse, length, num_consts, num_carry, jaxpr, linear, unroll, _split_transpose, *primals_in)
#     639 for _ in range(1 + num_carry):
#     640   nzs = const_nz + carry_nz + xs_nz
#     641   primal_jaxpr, num_res_out, nzs_out, in_fwd_res, tangent_jaxpr = \
# --> 642       ad.linearize_jaxpr(jaxpr, nzs, allow_fwds=allow_fwds,
#     643                          instantiate=carry_nz + [False] * num_ys)
#     644   carry_nz_out = nzs_out[:num_carry]
#     645   if carry_nz_out == carry_nz:
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:166, in linearize_jaxpr(jaxpr, nonzeros, instantiate, allow_fwds)
#     164   instantiate = (instantiate,) * len(jaxpr.jaxpr.outvars)
#     165 assert len(instantiate) == len(jaxpr.jaxpr.outvars)
# --> 166 return _linearize_jaxpr(jaxpr, tuple(nonzeros), tuple(instantiate),
#     167                         tuple(allow_fwds))
#
# File ~/anaconda3/envs/313/lib/python3.13/contextlib.py:85, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      82 @wraps(func)
#      83 def inner(*args, **kwds):
#      84     with self._recreate_cm():
# ---> 85         return func(*args, **kwds)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:195, in _linearize_jaxpr(jaxpr, nonzeros, instantiate, allow_fwds)
#     192 in_primals = [t.primal for t in tracers]
#     194 with core.set_current_trace(lin_trace, check_leaks=True):
# --> 195   ans = core.eval_jaxpr(jaxpr.jaxpr, jaxpr.consts, *tracers)
#     196   out_primals, out_tangents = unzip2(map(lin_trace.to_primal_tangent_pair, ans))
#     197   out_tangents = [instantiate_zeros(t) if inst else t
#     198                   for t, inst in zip(out_tangents, instantiate)]
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/core.py:722, in eval_jaxpr(jaxpr, consts, propagate_source_info, *args)
#     719 traceback = eqn.source_info.traceback if propagate_source_info else None
#     720 with source_info_util.user_context(
#     721     traceback, name_stack=name_stack), eqn.ctx.manager:
# --> 722   ans = eqn.primitive.bind(*subfuns, *map(read, eqn.invars), **bind_params)
#     723 if eqn.primitive.multiple_results:
#     724   foreach(write, eqn.outvars, ans)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/core.py:612, in Primitive.bind(self, *args, **params)
#     610 def bind(self, *args, **params):
#     611   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 612   return self._true_bind(*args, **params)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/core.py:628, in Primitive._true_bind(self, *args, **params)
#     626 trace_ctx.set_trace(eval_trace)
#     627 try:
# --> 628   return self.bind_with_trace(prev_trace, args, params)
#     629 finally:
#     630   trace_ctx.set_trace(prev_trace)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/core.py:638, in Primitive.bind_with_trace(self, trace, args, params)
#     635   with set_current_trace(trace):
#     636     return self.to_lojax(*args, **params)  # type: ignore
# --> 638 return trace.process_primitive(self, args, params)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:891, in LinearizeTrace.process_primitive(self, primitive, args, params)
#     889 lin = primitive_linearizations.get(primitive, fallback)
#     890 with core.set_current_trace(self.parent_trace):
# --> 891   primal_out, tangent_nzs_out, residuals, linearized = lin(
#     892       tangent_nzs, *primals_in, **params)
#     893 with (core.set_current_trace(self.tangent_trace),
#     894       source_info_util.set_name_stack(self._name_stack_suffix())):
#     895   tangent_out = linearized(residuals, *tangents_in)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:1052, in fallback_linearize_rule(_prim, _nonzeros, *primals, **params)
#    1050   raise NotImplementedError(msg)
#    1051 debug_jvp = debug_info("linearize_prim_jvp", jvp, primals, params)
# -> 1052 return linearize_from_jvp(lu.wrap_init(jvp, debug_info=debug_jvp),
#    1053                           _prim.multiple_results, _nonzeros, False, False,
#    1054                           primals, params)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:1086, in linearize_from_jvp(jvp, multiple_results, nonzeros, user_facing_symbolic_zeros, instantiate_input_zeros, primals, params)
#    1083 with core.set_current_trace(trace):
#    1084   tangent_args = [trace.new_arg(pe.PartialVal.unknown(a)) if nz else make_zero(a)
#    1085                   for a, nz in zip(tangent_avals, nonzeros)]
# -> 1086   out_primals, out_tangents = jvp.call_wrapped(
#    1087       tuple(primals), tuple(tangent_args), **params)
#    1089 if not multiple_results:
#    1090   out_primals = [out_primals]
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/linear_util.py:212, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     210 def call_wrapped(self, *args, **kwargs):
#     211   """Calls the transformed function"""
# --> 212   return self.f_transformed(*args, **kwargs)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/linear_util.py:397, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     395 @transformation_with_aux2
#     396 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 397   ans = _fun(*args, **kwargs)
#     398   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     399   if _store:
#     400     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     401     # the bwd function in a custom_vjp
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/ad_checkpoint.py:543, in remat_jvp(primals, tangents, jaxpr, prevent_cse, differentiated, policy)
#     541 nonzero_tangents = [t for t in tangents if type(t) is not ad_util.Zero]
#     542 jaxpr_jvp = pe.convert_constvars_jaxpr(jaxpr_jvp_.jaxpr)
# --> 543 outs = remat_p.bind(
#     544     *jaxpr_jvp_.consts, *primals, *nonzero_tangents, jaxpr=jaxpr_jvp,
#     545     prevent_cse=prevent_cse, differentiated=differentiated, policy=policy)
#     546 out_primals, out_tangents_ = split_list(outs, [len(jaxpr.outvars)])
#     547 out_tangents_ = iter(out_tangents_)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/core.py:612, in Primitive.bind(self, *args, **params)
#     610 def bind(self, *args, **params):
#     611   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 612   return self._true_bind(*args, **params)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/core.py:628, in Primitive._true_bind(self, *args, **params)
#     626 trace_ctx.set_trace(eval_trace)
#     627 try:
# --> 628   return self.bind_with_trace(prev_trace, args, params)
#     629 finally:
#     630   trace_ctx.set_trace(prev_trace)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/core.py:638, in Primitive.bind_with_trace(self, trace, args, params)
#     635   with set_current_trace(trace):
#     636     return self.to_lojax(*args, **params)  # type: ignore
# --> 638 return trace.process_primitive(self, args, params)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/interpreters/partial_eval.py:223, in JaxprTrace.process_primitive(self, primitive, tracers, params)
#     221 if primitive in custom_partial_eval_rules:
#     222   tracers = map(self.to_jaxpr_tracer, tracers)
# --> 223   return custom_partial_eval_rules[primitive](self, *tracers, **params)
#     224 else:
#     225   return self.default_process_primitive(primitive, tracers, params)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/ad_checkpoint.py:585, in remat_partial_eval(trace, jaxpr, *tracers, **params)
#     583 _, in_consts_ = unzip2(t.pval for t in tracers if t.pval.is_known())
#     584 _, in_consts = partition_list(in_used_known, in_consts_)
# --> 585 out_consts = core.eval_jaxpr(jaxpr_known_, (), *in_consts)
#     586 out_knowns, residuals = split_list(out_consts, [len(out_consts)-num_res])
#     588 # set up unknown outputs with a recipe to call remat
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/core.py:722, in eval_jaxpr(jaxpr, consts, propagate_source_info, *args)
#     719 traceback = eqn.source_info.traceback if propagate_source_info else None
#     720 with source_info_util.user_context(
#     721     traceback, name_stack=name_stack), eqn.ctx.manager:
# --> 722   ans = eqn.primitive.bind(*subfuns, *map(read, eqn.invars), **bind_params)
#     723 if eqn.primitive.multiple_results:
#     724   foreach(write, eqn.outvars, ans)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/core.py:612, in Primitive.bind(self, *args, **params)
#     610 def bind(self, *args, **params):
#     611   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 612   return self._true_bind(*args, **params)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/core.py:628, in Primitive._true_bind(self, *args, **params)
#     626 trace_ctx.set_trace(eval_trace)
#     627 try:
# --> 628   return self.bind_with_trace(prev_trace, args, params)
#     629 finally:
#     630   trace_ctx.set_trace(prev_trace)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/core.py:638, in Primitive.bind_with_trace(self, trace, args, params)
#     635   with set_current_trace(trace):
#     636     return self.to_lojax(*args, **params)  # type: ignore
# --> 638 return trace.process_primitive(self, args, params)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/interpreters/partial_eval.py:2073, in DynamicJaxprTrace.process_primitive(self, primitive, tracers, params)
#    2070 if primitive in custom_staging_rules:
#    2071   return custom_staging_rules[primitive](self, source_info, *jaxpr_tracers,
#    2072                                          **params)
# -> 2073 return self.default_process_primitive(
#    2074     primitive, jaxpr_tracers, params, source_info)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/interpreters/partial_eval.py:2087, in DynamicJaxprTrace.default_process_primitive(self, primitive, tracers, params, source_info)
#    2085 else:
#    2086   try:
# -> 2087     out_avals, effs = _cached_abstract_eval(primitive, *aval_qdds, **params)
#    2088   except Exception as e:
#    2089     # TODO(phawkins): remove this 3 months after the release of JAX v0.7.
#    2090     _verify_params_are_hashable(primitive, params)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/util.py:458, in multi_weakref_lru_cache.<locals>.wrapper(*orig_args, **orig_kwargs)
#     456 nr_weakrefs = len(acc_weakrefs)
#     457 if nr_weakrefs == 0:
# --> 458   return cached_call(_multi_weakref_placeholder,
#     459                      *orig_args, **orig_kwargs)
#     460 elif nr_weakrefs == 1:
#     461   # Put the single weakref first, and skip the MultiWeakRefCacheKey
#     462   return cached_call(acc_weakrefs[0],
#     463                      *args, **kwargs)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/util.py:442, in multi_weakref_lru_cache.<locals>.cache_miss(key, *args, **kwargs)
#     439 else:  # had 1 weakref, we had put it first as the `key`
#     440   orig_args, orig_kwargs = sentinel_to_referrents(
#     441       (args, kwargs), iter([weakref.ref(key)]), None)
# --> 442 return call(*orig_args, **orig_kwargs)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/interpreters/partial_eval.py:1911, in _cached_abstract_eval(primitive, *aval_qdds, **params)
#    1909 @multi_weakref_lru_cache
#    1910 def _cached_abstract_eval(primitive: core.Primitive, *aval_qdds, **params):
# -> 1911   return primitive.abstract_eval(*aval_qdds, **params)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/core.py:677, in _effect_free_abstract_eval.<locals>.abstract_eval_(*args, **kwargs)
#     676 def abstract_eval_(*args, **kwargs):
# --> 677   return abstract_eval(*args, **kwargs), no_effects
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/lax/utils.py:158, in standard_abstract_eval(prim, shape_rule, dtype_rule, weak_type_rule, sharding_rule, vma_rule, unreduced_rule, *avals, **kwargs)
#     156 if least_specialized is core.ShapedArray:
#     157   core.check_avals_context_mesh(avals, prim.name)
# --> 158   out_shape, out_dtype, out_sharding = call_shape_dtype_sharding_rule(
#     159       prim, shape_rule, dtype_rule, sharding_rule, unreduced_rule, False,
#     160       *avals, **kwargs)
#     161   out_vma = vma_rule(*avals, **kwargs)
#     162   out_mem_space = _default_memory_space_rule(prim, *avals, **kwargs)
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/lax/utils.py:101, in call_shape_dtype_sharding_rule(prim, shape_rule, dtype_rule, sharding_rule, unreduced_rule, multi_out, *avals, **kwargs)
#      99 def call_shape_dtype_sharding_rule(prim, shape_rule, dtype_rule, sharding_rule,
#     100                                    unreduced_rule, multi_out, *avals, **kwargs):
# --> 101   out_shapes = shape_rule(*avals, **kwargs)
#     102   out_dtypes = dtype_rule(*avals, **kwargs)
#     103   num_out = len(out_shapes) if multi_out else None
#
# File ~/anaconda3/envs/313/lib/python3.13/site-packages/jax/_src/lax/slicing.py:1363, in _slice_shape_rule(operand, start_indices, limit_indices, strides)
#    1361   raise TypeError(msg.format(start_indices))
#    1362 if not config.dynamic_shapes.value:
# -> 1363   if not all(map(operator.ge, limit_indices, start_indices)):
#    1364     msg = ("slice limit_indices must be greater than or equal to start_indices,"
#    1365           " got start_indices {} and limit_indices {}.")
#    1366     raise TypeError(msg.format(start_indices, limit_indices))
#
# KeyboardInterrupt:

# %%
for alpha in [1.0, 0.97, 0.0]:
    plt.hist(np.array(grads[str(alpha)])[:,0], alpha=1, label=alpha)
plt.legend()

# %%
params_box = {'gamma': [10.,  40.],
                 'epsilon': [0.20, 30.00],
                 'rho': [0.0, 0.0],
                 'm': [0.03, 0.60],
                 'c': [1.0, 1.0],
                 'beta_trend': [-1.*0.01, -0.*0.01],
                 'bs1': [-4., 4.],
                 'bs2': [0., 8.],
                 'bs3': [-4., 4.],
                 'bs4': [0., 8.],
                 'bs5': [0., 8.],
                 'bs6': [0., 8.],
                 'sigma': [1., 5.],
                 'tau': [0.1, 0.5],
                 'omega': [np.exp(-4.5), np.exp(-4.5)],
                 'omegas1': [-10., -0.],
                 'omegas2': [-10., -0.],
                 'omegas3': [-10., -0.],
                 'omegas4': [-10., -0.],
                 'omegas5': [-10., -0.],
                 'omegas6': [-10., -0.]}

# %%
MAIN_SEED = 631409
key = jax.random.key(MAIN_SEED)
np.random.seed(MAIN_SEED)

RW_SD = pp.RWSigma(
    sigmas={
        "gamma": 0.02,
        "m": 0.02,
        "rho": 0.0,
        "epsilon": 0.02,
        "omega": 0.02,
        "c": 0.02,
        "beta_trend": 0.02,
        "sigma": 0.02,
        "tau": 0.02,
        "bs1": 0.02,
        "bs2": 0.02,
        "bs3": 0.02,
        "bs4": 0.02,
        "bs5": 0.02,
        "bs6": 0.02,
        "omegas1": 0.02,
        "omegas2": 0.02,
        "omegas3": 0.02,
        "omegas4": 0.02,
        "omegas5": 0.02,
        "omegas6": 0.02,
    },
    init_names=[],
)

COOLING_RATE = 0.5
NP_FITR = NP_EVAL = 10000

N_TRIALS = 100
NREPS_EVAL = 1
NFITR_MIF = 40
NFITR_GD = 60


# NREPS_EVAL = 1
# NFITR_MIF = 2 #40
# NFITR_GD = 2
#N_TRIALS = 2
alphas = [0.,1.,0.97]
daccas_pre = []
daccas_mif = []
daccas_alphas = {str(alpha) : [] for alpha in alphas}

starting_logliks = []
mif_logliks = []


dacca_obj = pp.dacca(gamma=False)
for trial in tqdm(range(N_TRIALS)):
    dacca_obj.results_history.clear()
    key, subkey = jax.random.split(key)
    theta = pp.Pomp.sample_params(params_box, 1, key=subkey)[0]
    key, subkey = jax.random.split(key)
    dacca_obj.pfilter(J=NP_EVAL, reps=NREPS_EVAL, key=subkey, theta=theta)
    print('trial ' + str(trial) + ' init :', dacca_obj.results())
    
    key, subkey = jax.random.split(key)
    dacca_obj.mif(
            theta=theta,
            rw_sd=RW_SD,
            M=NFITR_MIF,
            a=COOLING_RATE,
            J=NP_FITR,
            key=subkey
        ) #0.95
    
    #warm_start_theta = dacca_obj.theta
    trace = np.asarray(dacca_obj.results_history[-1].traces_da)
    argmax = int(trace[0,:,0].argmax())

    warm_start_theta = pd.DataFrame(trace[0,argmax,1:], index=dacca_obj.canonical_param_names)[0]
    warm_start_theta = [{k : float(v) for k, v in warm_start_theta.items()}]
    
    key, subkey = jax.random.split(key)
    dacca_obj.pfilter(J=NP_EVAL, reps=NREPS_EVAL)
    print('trial ' + str(trial) + ' mif 40:', dacca_obj.results())
    daccas_pre.append(dacca_obj.results())

    key, subkey = jax.random.split(key)
    dacca_obj.mif(
                theta=theta,
                rw_sd=RW_SD,
                M=NFITR_MIF+NFITR_GD*3,
                a=COOLING_RATE,
                J=NP_FITR,
                key=subkey
            )
    
    key, subkey = jax.random.split(key)
    dacca_obj.pfilter(J=NP_EVAL, reps=NREPS_EVAL)
    print('trial ' + str(trial) + ' mif 100:', dacca_obj.results())
    daccas_mif.append(dacca_obj.results())

    for alpha, eta in tqdm(zip(alphas, [0.1, 0.05, 0.2])):
        key, subkey = jax.random.split(key)
        dacca_obj.train(J=NP_FITR, M=NFITR_GD, 
                          theta=warm_start_theta,
                        optimizer='SGD', eta=eta, 
                          ls=False, scale=False, 
                          alpha=alpha, key=subkey)
        key, subkey = jax.random.split(key)
        dacca_obj.pfilter(J=NP_EVAL, reps=NREPS_EVAL)
        print('trial ' + str(trial) + ' alpha=', str(alpha),':', dacca_obj.results())
        daccas_alphas[str(alpha)].append(dacca_obj.results())

pd.concat({k : pd.concat(daccas_alphas[str(k)]).reset_index(drop=True) for k in alphas}, axis=0).to_csv('runs.csv')
pd.concat(daccas_mif).reset_index(drop=True).to_csv('mif.csv')
pd.concat(daccas_pre).reset_index(drop=True).to_csv('pre.csv')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 58
#      56 dacca_obj.results_history.clear()
#      57 key, subkey = jax.random.split(key)
# ---> 58 theta = pp.Pomp.sample_params(params_box, 1, key=subkey)[0]
#      59 key, subkey = jax.random.split(key)
#      60 dacca_obj.pfilter(J=NP_EVAL, reps=NREPS_EVAL, key=subkey, theta=theta)
#
# NameError: name 'params_box' is not defined

# %%
dacca_obj.results()
# Out:
#          logLik  se     gamma         m  rho   epsilon     omega    c  \
# 0 -24867.998047 NaN  1.299844 -3.120551 -inf  0.985573 -7.560599  inf
#
#    beta_trend     sigma  ...       bs3       bs4       bs5     bs6   omegas1  \
# 0  -23.142998  1.552134  ... -5.032645 -2.040696  1.194478 -1.7298 -0.868005
#
#     omegas2   omegas3   omegas4   omegas5   omegas6
# 0 -5.157048 -2.049488 -6.195749 -2.077846 -0.539867
#
# [1 rows x 23 columns]

# %%
[r['traces'] for r in dacca_obj.results_history if r['method']=='mif']
